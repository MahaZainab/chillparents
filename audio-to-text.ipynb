# %% [markdown]
# ## Audio to Text

# %% [markdown]
# ### In this Module we are going to convert our audio into text

# %%
import torch
from transformers import AutoModelForSpeechSeq2Seq, AutoProcessor, pipeline
from datasets import load_dataset

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"
torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32

model_id = "openai/whisper-large-v3"

model = AutoModelForSpeechSeq2Seq.from_pretrained(
    model_id, torch_dtype=torch_dtype, low_cpu_mem_usage=True, use_safetensors=True
)
model.to(device)

processor = AutoProcessor.from_pretrained(model_id)

pipe = pipeline(
    "automatic-speech-recognition",
    model=model,
    tokenizer=processor.tokenizer,
    feature_extractor=processor.feature_extractor,
    torch_dtype=torch_dtype,
    device=device,
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 6
#       2 torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32
#       4 model_id = "openai/whisper-large-v3"
# ----> 6 model = AutoModelForSpeechSeq2Seq.from_pretrained(
#       7     model_id, torch_dtype=torch_dtype, low_cpu_mem_usage=True, use_safetensors=True
#       8 )
#       9 model.to(device)
#      11 processor = AutoProcessor.from_pretrained(model_id)
#
# File c:\Program Files\Python312\Lib\site-packages\transformers\models\auto\auto_factory.py:564, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     562 elif type(config) in cls._model_mapping.keys():
#     563     model_class = _get_model_class(config, cls._model_mapping)
# --> 564     return model_class.from_pretrained(
#     565         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     566     )
#     567 raise ValueError(
#     568     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     569     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     570 )
#
# File c:\Program Files\Python312\Lib\site-packages\transformers\modeling_utils.py:4225, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4215     if dtype_orig is not None:
#    4216         torch.set_default_dtype(dtype_orig)
#    4218     (
#    4219         model,
#    4220         missing_keys,
#    4221         unexpected_keys,
#    4222         mismatched_keys,
#    4223         offload_index,
#    4224         error_msgs,
# -> 4225     ) = cls._load_pretrained_model(
#    4226         model,
#    4227         state_dict,
#    4228         loaded_state_dict_keys,  # XXX: rename?
#    4229         resolved_archive_file,
#    4230         pretrained_model_name_or_path,
#    4231         ignore_mismatched_sizes=ignore_mismatched_sizes,
#    4232         sharded_metadata=sharded_metadata,
#    4233         _fast_init=_fast_init,
#    4234         low_cpu_mem_usage=low_cpu_mem_usage,
#    4235         device_map=device_map,
#    4236         offload_folder=offload_folder,
#    4237         offload_state_dict=offload_state_dict,
#    4238         dtype=torch_dtype,
#    4239         hf_quantizer=hf_quantizer,
#    4240         keep_in_fp32_modules=keep_in_fp32_modules,
#    4241         gguf_path=gguf_path,
#    4242         weights_only=weights_only,
#    4243     )
#    4245 # make sure token embedding weights are still tied if needed
#    4246 model.tie_weights()
#
# File c:\Program Files\Python312\Lib\site-packages\transformers\modeling_utils.py:4728, in PreTrainedModel._load_pretrained_model(cls, model, state_dict, loaded_keys, resolved_archive_file, pretrained_model_name_or_path, ignore_mismatched_sizes, sharded_metadata, _fast_init, low_cpu_mem_usage, device_map, offload_folder, offload_state_dict, dtype, hf_quantizer, keep_in_fp32_modules, gguf_path, weights_only)
#    4724                 set_module_tensor_to_device(
#    4725                     model_to_load, key, "cpu", torch.empty(*param.size(), dtype=dtype)
#    4726                 )
#    4727     else:
# -> 4728         new_error_msgs, offload_index, state_dict_index = _load_state_dict_into_meta_model(
#    4729             model_to_load,
#    4730             state_dict,
#    4731             start_prefix,
#    4732             expected_keys,
#    4733             device_map=device_map,
#    4734             offload_folder=offload_folder,
#    4735             offload_index=offload_index,
#    4736             state_dict_folder=state_dict_folder,
#    4737             state_dict_index=state_dict_index,
#    4738             dtype=dtype,
#    4739             hf_quantizer=hf_quantizer,
#    4740             is_safetensors=is_safetensors,
#    4741             keep_in_fp32_modules=keep_in_fp32_modules,
#    4742             unexpected_keys=unexpected_keys,
#    4743         )
#    4744         error_msgs += new_error_msgs
#    4745 else:
#    4746     # Sharded checkpoint or whole but low_cpu_mem_usage==True
#
# File c:\Program Files\Python312\Lib\site-packages\transformers\modeling_utils.py:937, in _load_state_dict_into_meta_model(model, state_dict, start_prefix, expected_keys, device_map, offload_folder, offload_index, state_dict_folder, state_dict_index, dtype, hf_quantizer, is_safetensors, keep_in_fp32_modules, unexpected_keys, pretrained_model_name_or_path)
#     935             set_module_kwargs["dtype"] = torch.float32
#     936     else:
# --> 937         param = param.to(dtype)
#     939 # For compatibility with PyTorch load_state_dict which converts state dict dtype to existing dtype in model, and which
#     940 # uses `param.copy_(input_param)` that preserves the contiguity of the parameter in the model.
#     941 # Reference: https://github.com/pytorch/pytorch/blob/db79ceb110f6646523019a59bbd7b838f43d4a86/torch/nn/modules/module.py#L2040C29-L2040C29
#     943 old_param = model
#
# KeyboardInterrupt:

# %%
dataset = load_dataset("distil-whisper/librispeech_long", "clean", split="validation")
sample = dataset[0]["audio"]

result = pipe(sample)
print(result["text"])
# Out:
# C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\huggingface_hub\file_download.py:159: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\PC\.cache\huggingface\hub\datasets--distil-whisper--librispeech_long. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Generating validation split: 100%|██████████| 1/1 [00:00<00:00, 11.40 examples/s]
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File c:\Program Files\Python312\Lib\tempfile.py:256, in _mkstemp_inner(dir, pre, suf, flags, output_type)
#     255 try:
# --> 256     fd = _os.open(file, flags, 0o600)
#     257 except FileExistsError:
#
# PermissionError: [Errno 13] Permission denied: 'c:\\Program Files\\Python312\\Lib\\site-packages\\librosa\\core\\__pycache__\\tmplg9s7596'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 dataset = load_dataset("distil-whisper/librispeech_long", "clean", split="validation")
# ----> 2 sample = dataset[0]["audio"]
#       4 result = pipe(sample)
#       5 print(result["text"])
#
# File c:\Program Files\Python312\Lib\site-packages\datasets\arrow_dataset.py:2762, in Dataset.__getitem__(self, key)
#    2760 def __getitem__(self, key):  # noqa: F811
#    2761     """Can be used to index columns (by string names) or rows (by integer index or iterable of indices or bools)."""
# -> 2762     return self._getitem(key)
#
# File c:\Program Files\Python312\Lib\site-packages\datasets\arrow_dataset.py:2747, in Dataset._getitem(self, key, **kwargs)
#    2745 formatter = get_formatter(format_type, features=self._info.features, **format_kwargs)
#    2746 pa_subtable = query_table(self._data, key, indices=self._indices)
# -> 2747 formatted_output = format_table(
#    2748     pa_subtable, key, formatter=formatter, format_columns=format_columns, output_all_columns=output_all_columns
#    2749 )
#    2750 return formatted_output
#
# File c:\Program Files\Python312\Lib\site-packages\datasets\formatting\formatting.py:639, in format_table(table, key, formatter, format_columns, output_all_columns)
#     637 python_formatter = PythonFormatter(features=formatter.features)
#     638 if format_columns is None:
# --> 639     return formatter(pa_table, query_type=query_type)
#     640 elif query_type == "column":
#     641     if key in format_columns:
#
# File c:\Program Files\Python312\Lib\site-packages\datasets\formatting\formatting.py:403, in Formatter.__call__(self, pa_table, query_type)
#     401 def __call__(self, pa_table: pa.Table, query_type: str) -> Union[RowFormat, ColumnFormat, BatchFormat]:
#     402     if query_type == "row":
# --> 403         return self.format_row(pa_table)
#     404     elif query_type == "column":
#     405         return self.format_column(pa_table)
#
# File c:\Program Files\Python312\Lib\site-packages\datasets\formatting\formatting.py:444, in PythonFormatter.format_row(self, pa_table)
#     442     return LazyRow(pa_table, self)
#     443 row = self.python_arrow_extractor().extract_row(pa_table)
# --> 444 row = self.python_features_decoder.decode_row(row)
#     445 return row
#
# File c:\Program Files\Python312\Lib\site-packages\datasets\formatting\formatting.py:222, in PythonFeaturesDecoder.decode_row(self, row)
#     221 def decode_row(self, row: dict) -> dict:
# --> 222     return self.features.decode_example(row) if self.features else row
#
# File c:\Program Files\Python312\Lib\site-packages\datasets\features\features.py:2045, in Features.decode_example(self, example, token_per_repo_id)
#    2030 def decode_example(self, example: dict, token_per_repo_id: Optional[Dict[str, Union[str, bool, None]]] = None):
#    2031     """Decode example with custom feature decoding.
#    2032
#    2033     Args:
#    (...)
#    2041         `dict[str, Any]`
#    2042     """
#    2044     return {
# -> 2045         column_name: decode_nested_example(feature, value, token_per_repo_id=token_per_repo_id)
#    2046         if self._column_requires_decoding[column_name]
#    2047         else value
#    2048         for column_name, (feature, value) in zip_dict(
#    2049             {key: value for key, value in self.items() if key in example}, example
#    2050         )
#    2051     }
#
# File c:\Program Files\Python312\Lib\site-packages\datasets\features\features.py:1405, in decode_nested_example(schema, obj, token_per_repo_id)
#    1402 elif isinstance(schema, (Audio, Image, Video)):
#    1403     # we pass the token to read and decode files from private repositories in streaming mode
#    1404     if obj is not None and schema.decode:
# -> 1405         return schema.decode_example(obj, token_per_repo_id=token_per_repo_id)
#    1406 return obj
#
# File c:\Program Files\Python312\Lib\site-packages\datasets\features\audio.py:191, in Audio.decode_example(self, value, token_per_repo_id)
#     189 array = array.T
#     190 if self.mono:
# --> 191     array = librosa.to_mono(array)
#     192 if self.sampling_rate and self.sampling_rate != sampling_rate:
#     193     array = librosa.resample(array, orig_sr=sampling_rate, target_sr=self.sampling_rate)
#
# File c:\Program Files\Python312\Lib\site-packages\lazy_loader\__init__.py:83, in attach.<locals>.__getattr__(name)
#      81 submod_path = f"{package_name}.{attr_to_modules[name]}"
#      82 submod = importlib.import_module(submod_path)
# ---> 83 attr = getattr(submod, name)
#      85 # If the attribute lives in a file (module) with the same
#      86 # name as the attribute, ensure that the attribute and *not*
#      87 # the module is accessible on the package.
#      88 if name == attr_to_modules[name]:
#
# File c:\Program Files\Python312\Lib\site-packages\lazy_loader\__init__.py:82, in attach.<locals>.__getattr__(name)
#      80 elif name in attr_to_modules:
#      81     submod_path = f"{package_name}.{attr_to_modules[name]}"
# ---> 82     submod = importlib.import_module(submod_path)
#      83     attr = getattr(submod, name)
#      85     # If the attribute lives in a file (module) with the same
#      86     # name as the attribute, ensure that the attribute and *not*
#      87     # the module is accessible on the package.
#
# File c:\Program Files\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:995, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Program Files\Python312\Lib\site-packages\librosa\core\audio.py:20
#      18 from numba import jit, stencil, guvectorize
#      19 from .fft import get_fftlib
# ---> 20 from .convert import frames_to_samples, time_to_samples
#      21 from .._cache import cache
#      22 from .. import util
#
# File c:\Program Files\Python312\Lib\site-packages\librosa\core\convert.py:7
#       5 import re
#       6 import numpy as np
# ----> 7 from . import notation
#       8 from ..util.exceptions import ParameterError
#       9 from ..util.decorators import vectorize
#
# File c:\Program Files\Python312\Lib\site-packages\librosa\core\notation.py:1008
#    1001     acc_str = acc_map_inv[np.sign(acc_index) * 2] * int(
#    1002         abs(acc_index) // 2
#    1003     ) + acc_map_inv[np.sign(acc_index)] * int(abs(acc_index) % 2)
#    1005     return raw_output + acc_str
# -> 1008 @jit(nopython=True, nogil=True, cache=True)
#    1009 def __o_fold(d):
#    1010     """Compute the octave-folded interval.
#    1011
#    1012     This maps intervals to the range [1, 2).
#    (...)
#    1016     documentation.
#    1017     """
#    1018     return d * (2.0 ** -np.floor(np.log2(d)))
#
# File c:\Program Files\Python312\Lib\site-packages\numba\core\decorators.py:225, in _jit.<locals>.wrapper(func)
#     221 disp = dispatcher(py_func=func, locals=locals,
#     222                   targetoptions=targetoptions,
#     223                   **dispatcher_args)
#     224 if cache:
# --> 225     disp.enable_caching()
#     226 if sigs is not None:
#     227     # Register the Dispatcher to the type inference mechanism,
#     228     # even though the decorator hasn't returned yet.
#     229     from numba.core import typeinfer
#
# File c:\Program Files\Python312\Lib\site-packages\numba\core\dispatcher.py:808, in Dispatcher.enable_caching(self)
#     807 def enable_caching(self):
# --> 808     self._cache = FunctionCache(self.py_func)
#
# File c:\Program Files\Python312\Lib\site-packages\numba\core\caching.py:601, in Cache.__init__(self, py_func)
#     599 self._name = repr(py_func)
#     600 self._py_func = py_func
# --> 601 self._impl = self._impl_class(py_func)
#     602 self._cache_path = self._impl.locator.get_cache_path()
#     603 # This may be a bit strict but avoids us maintaining a magic number
#
# File c:\Program Files\Python312\Lib\site-packages\numba\core\caching.py:333, in CacheImpl.__init__(self, py_func)
#     331 source_path = inspect.getfile(py_func)
#     332 for cls in self._locator_classes:
# --> 333     locator = cls.from_function(py_func, source_path)
#     334     if locator is not None:
#     335         break
#
# File c:\Program Files\Python312\Lib\site-packages\numba\core\caching.py:180, in _SourceFileBackedLocatorMixin.from_function(cls, py_func, py_file)
#     178 self = cls(py_func, py_file)
#     179 try:
# --> 180     self.ensure_cache_path()
#     181 except OSError:
#     182     # Cannot ensure the cache directory exists or is writable
#     183     return
#
# File c:\Program Files\Python312\Lib\site-packages\numba\core\caching.py:107, in _CacheLocator.ensure_cache_path(self)
#     105 os.makedirs(path, exist_ok=True)
#     106 # Ensure the directory is writable by trying to write a temporary file
# --> 107 tempfile.TemporaryFile(dir=path).close()
#
# File c:\Program Files\Python312\Lib\tempfile.py:582, in NamedTemporaryFile(mode, buffering, encoding, newline, suffix, prefix, dir, delete, errors, delete_on_close)
#     580     return fd
#     581 try:
# --> 582     file = _io.open(dir, mode, buffering=buffering,
#     583                     newline=newline, encoding=encoding, errors=errors,
#     584                     opener=opener)
#     585     try:
#     586         raw = getattr(file, 'buffer', file)
#
# File c:\Program Files\Python312\Lib\tempfile.py:579, in NamedTemporaryFile.<locals>.opener(*args)
#     577 def opener(*args):
#     578     nonlocal name
# --> 579     fd, name = _mkstemp_inner(dir, prefix, suffix, flags, output_type)
#     580     return fd
#
# File c:\Program Files\Python312\Lib\tempfile.py:262, in _mkstemp_inner(dir, pre, suf, flags, output_type)
#     258     continue    # try again
#     259 except PermissionError:
#     260     # This exception is thrown when a directory with the chosen name
#     261     # already exists on windows.
# --> 262     if (_os.name == 'nt' and _os.path.isdir(dir) and
#     263         _os.access(dir, _os.W_OK)):
#     264         continue
#     265     else:
#
# KeyboardInterrupt:
